# %%
#     1)DATA IMPORTING,DATA CLEANING AND TRANSFORMATION

# %%
#importing first 10 rows of data
import pandas as pd
ccfdd=pd.read_csv('C:/Users/DELL/Documents/creditcard.csv')
ccfdd.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
#shape of data
ccfdd.shape
# Out:
# (284807, 31)

# %%
#discriptino of data
print(ccfdd.describe())
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
#how much of data is useful
#selecting all columns excluding class column
x=ccfdd.iloc[:, :-1].values
print(x.shape)
#selecting only the class column
y=ccfdd.iloc[:, -1].values
print(y.shape)
# Out:
# (284807, 30)
# (284807,)

# %%
#     2)VISUALISATION OF DATA

# %%
#basic visualisation
#histgram of all parameter
import matplotlib.pyplot as plt
ccfdd.hist(figsize=(20,20))
plt.show()

# %%
import matplotlib.gridspec as gridspec
figure(figsize=(4,4))
plt.scatter(ccfdd['Time'][ccfdd.Class==1], ccfdd['Amount'][ccfdd.Class==1], alpha=0.5)
plt.margins(0)
plt.title('The Amounts of Every Frauds')
plt.xlabel('Time')
plt.ylabel('Euro')
# Out:
# Text(0, 0.5, 'Euro')

# %%
figure(figsize=(4,4))
plt.scatter(ccfdd['Time'][ccfdd.Class==0], ccfdd['Amount'][ccfdd.Class==0])
plt.margins(0)
plt.title('The Amounts of Every Normal Transactions')
plt.xlabel('Time')
plt.ylabel('Euro')
# Out:
# Text(0, 0.5, 'Euro')

# %%
#correlation matrix
import matplotlib.pyplot as plt
import seaborn as sb
c_m=ccfdd.corr()
fig=plt.figure(figsize=(10,8))
sb.heatmap(c_m,vmax=0.8,square=True)
plt.show()

# %%
#     3)ALGORITHMS,TRAINING AND PREDICTION

# %%
#trai test spilt method

from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#dision tree cassifier
print("using decision tree algorithm")
c=DecisionTreeClassifier(max_depth=4)
c.fit(x_train,y_train)
y_pred=c.predict(x_test)
print("predicted value=",y_pred)

#accuracy
acc=metrics.accuracy_score(y_test,y_pred)*100
print("accuracy=",acc)

#precision
prs=precision_score(y_test,y_pred,pos_label=1)
print("precision=",prs)

#recall
rcl=recall_score(y_test,y_pred,pos_label=1)
print("recall=",rcl)

#f1-score
f1s=f1_score(y_test,y_pred,pos_label=1)
print("f1-scare=",f1s)
# Out:
# using decision tree algorithm
# predicted value= [0 0 0 ... 0 0 0]
# accuracy= 99.93328885923948
# precision= 0.8072289156626506
# recall= 0.7528089887640449
# f1-scare= 0.7790697674418604

# %%
#confusion matrics for decision tree
from sklearn.metrics import confusion_matrix
label=['valid','fraud']
cmt=confusion_matrix(y_test,y_pred)
plt.figure(figsize=(10,10))
sb.heatmap(cmt,xticklabels=label,yticklabels=label,annot=True,fmt="d");
plt.title("confusion matrix using random forest")
plt.ylabel('True class')
plt.xlabel('predicted class')
plt.show()

# %%
#applying random forest algorithm
print("using random forest algorithm")
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred1=rfc.predict(x_test)
print("predicted value=",y_pred1)

#accuracy
acc1=accuracy_score(y_test,y_pred1)
print("accuracy=",acc1)

#precision
prs1=precision_score(y_test,y_pred1)
print("precision=",prs1)

#recall
rcl1=recall_score(y_test,y_pred1)
print("recall=",rcl1)

#f1-score
f1s1=f1_score(y_test,y_pred1)
print("f1-score=",f1s1)
# Out:
# using random forest algorithm
# predicted value= [0 0 0 ... 0 0 0]
# accuracy= 0.9995611109160493
# precision= 0.9102564102564102
# recall= 0.797752808988764
# f1-score= 0.8502994011976048

# %%
#confusion matrix for random forest
labels=['valid','fraud']
cmt1=confusion_matrix(y_test,y_pred1)
plt.figure(figsize=(10,10))
sb.heatmap(cmt1,xticklabels=label,yticklabels=label,annot=True,fmt="d");
plt.title("confusion matrix using random forest")
plt.ylabel('True class')
plt.xlabel('predicted class')
plt.show()

# %%
#     4)ACCURACY AND MATRICS

# %%
#finding no of fraud cases
frd=ccfdd[ccfdd['Class']==1]
vld=ccfdd[ccfdd['Class']==0]
outlierfraction=len(frd)/float(len(vld))
print(outlierfraction)
print("no of fraud credit cards= {}".format(len(frd)))
print("no of valid credit cards= {}".format(len(vld)))
# Out:
# 0.0017304750013189597
# no of fraud credit cards= 492
# no of valid credit cards= 284315

# %%
#how much amount is valid
print("valid ammount details")
vld.Amount.describe()
# Out:
# valid ammount details
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#how much ammount is fraud
print("fraud ammount details")
frd.Amount.describe()
# Out:
# fraud ammount details
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sb
sb.set_context("paper")
sb.set_style("white",{"font.family":"serif","font.serif":["times","palatino""serif"]})
ccfdd['Class'].value_counts().plot(kind='bar')
plt.show()
